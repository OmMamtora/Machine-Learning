# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-2.3.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting graphviz>=0.9 (from dtreeviz)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pandas in c:\users\om\anaconda3\lib\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\om\anaconda3\lib\site-packages (from dtreeviz) (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\om\anaconda3\lib\site-packages (from dtreeviz) (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\om\anaconda3\lib\site-packages (from dtreeviz) (3.10.0)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\om\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\om\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\om\anaconda3\lib\site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\om\anaconda3\lib\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\om\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\om\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\om\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Downloading dtreeviz-2.3.2-py3-none-any.whl (102 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: colour, graphviz, dtreeviz
#
#    ------------- -------------------------- 1/3 [graphviz]
#    -------------------------- ------------- 2/3 [dtreeviz]
#    ---------------------------------------- 3/3 [dtreeviz]
#
# Successfully installed colour-0.1.5 dtreeviz-2.3.2 graphviz-0.21

# %%
import graphviz.backend as be

from sklearn.datasets import load_iris
from dtreeviz.trees import *
from sklearn.tree import DecisionTreeClassifier,plot_tree
from IPython.display import Image, display_svg, SVG

# %%
clas = DecisionTreeClassifier(max_depth=2)

iris = load_iris()

X_train = iris.data
X_test = iris.target

clas.fit(X_train, X_test)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
plot_tree(clas)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# # Classification

# %%
import dtreeviz


viz = dtreeviz.dtreeviz(clas, X_train,feature_names = iris.feature_names)

viz
# Out:
# C:\Users\Om\AppData\Local\Temp\ipykernel_21048\2467101087.py:4: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 import dtreeviz
# ----> 4 viz = dtreeviz.dtreeviz(clas, X_train,feature_names = iris.feature_names)
#       6 viz
#
# File c:\Users\Om\anaconda3\Lib\site-packages\dtreeviz\compatibility.py:254, in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     251 shadow_tree = ShadowDecTree.get_shadow_tree(tree_model, X_train, y_train, feature_names, target_name, class_names,
#     252                                             tree_index)
#     253 model = DTreeVizAPI(shadow_tree)
# --> 254 return model.view(precision, orientation,
#     255                   instance_orientation,
#     256                   show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X,
#     257                   max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize,
#     258                   fontname, title, title_fontsize, colors=colors, scale=scale)
#
# File c:\Users\Om\anaconda3\Lib\site-packages\dtreeviz\trees.py:837, in DTreeVizAPI.view(self, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, leaftype, highlight_path, x, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale, ai_chat)
#     835 tmp = tempfile.gettempdir()
#     836 if x is not None:
# --> 837     path = self.shadow_tree.predict_path(x)
#     838     highlight_path = [n.id for n in path]
#     839     path_summary_text = _summarize_path_for_chat(path)
#
# File c:\Users\Om\anaconda3\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:340, in ShadowDecTree.predict_path(self, x)
#     337     return walk(t.right, x, path)
#     339 path = []
# --> 340 walk(self.root, x, path)
#     341 return path
#
# File c:\Users\Om\anaconda3\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:335, in ShadowDecTree.predict_path.<locals>.walk(t, x, path)
#     333 if t.isleaf():
#     334     return None
# --> 335 if self.shouldGoLeftAtSplit(t.id, x[t.feature()]):
#     336     return walk(t.left, x, path)
#     337 return walk(t.right, x, path)
#
# TypeError: 'int' object is not subscriptable
