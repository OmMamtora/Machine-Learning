# %%
import pandas as pd
import numpy as np
import pickle

# %%
load_model = pickle.load(open('Employee Attrition Status.pkl', 'rb'))

process = load_model['process']
model = load_model['model']

# %%
input_data = pd.DataFrame({
    'BusinessTravel':['Travel_Rarely'],
    'Department':['Sales'],
    'EducationField':['Life Sciences'],
    'Gender':['Male'],
    'JobRole':['Sales Executive'],
    'MaritalStatus':['Single'],
    'OverTime':['No'],
    
    'Age':[30],
    'DailyRate':[800],
    'DistanceFromHome':[10],
    'Education':[3],
    'EnvironmentSatisfaction':[3],
    'HourlyRate':[60],
    'JobInvolvement':[3],
    'JobLevel':[2],
    'JobSatisfaction':[3],
    'MonthlyIncome':[5000],
    'MonthlyRate':[15000],
    'NumCompaniesWorked':[2],
    'PercentSalaryHike':[15],
    'PerformanceRating':[3],
    'RelationshipSatisfaction':[3],
    'StockOptionLevel':[1],
    'TotalWorkingYears':[8],
    'TrainingTimesLastYear':[3],
    'WorkLifeBalance':[3],
    'YearsAtCompany':[5],
    'YearsInCurrentRole':[3],
    'YearsSinceLastPromotion':[1],
    'YearsWithCurrManager':[3]
})

# %%
input_data.head()
# Out:
#   BusinessTravel Department EducationField Gender          JobRole  \
# 0  Travel_Rarely      Sales  Life Sciences   Male  Sales Executive
#
#   MaritalStatus OverTime  Age  DailyRate  DistanceFromHome  ...  \
# 0        Single       No   30        800                10  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         3                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      3                3               5
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   3                        1                     3
#
# [1 rows x 30 columns]

# %% [markdown]
# # Encoding and transforming the data

# %%
processed = process.transform(input_data)

# %% [markdown]
# # Finding prediction and probability of that

# %% [markdown]
# ### Attrition : 1 leave(Yes) and
# ### 0 : Stay(No)

# %%
y_pred = model.predict(processed)
y_pred_probability = model.predict_proba(processed)

# %%
result = {
    'prediction' : y_pred,
    'Probability to leave' : y_pred_probability
}

# %%
result # Here we got two prediction value first is for 0:-> Stay(No) and second is for 1:->Leave(Yes)
# Out:
# {'prediction': array([0]),
#  'Probability to leave': array([[0.72917748, 0.27082252]])}

# %%
y_pred_prob = model.predict_proba(processed)[0][1]

if y_pred_prob > 0.7:
    print("High Attrition Risk to Leave")
elif y_pred_prob > 0.4:
    print("Medium Attrition Risk to Leave")
else:
    print("Low Attration Risk")
# Out:
# Low Attration Risk
