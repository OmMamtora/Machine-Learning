# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipeline.pkl','rb'))

# %%
# Pclass 	Sex 	Age 	SibSp 	Parch 	Fare 	Embarked

test_input = np.array([2, 'Male', 31, 0, 0,10.5, 's'], dtype = object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\Om\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
